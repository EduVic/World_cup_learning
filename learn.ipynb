# %% [markdown]
# World Cup Learning
# ------------------
#
# Here I try to predict fifa world cup matches results, based on the knowledge of previous matches from the cups since the year 1950.
#
# I'll use a MLP neural network classifier, my inputs will be the past matches (replacing each team name with a lot of stats from both), and my output will be a number indicating the result (0 = tie, 1 = wins team1, 2 = wins team2).
#
# I'll be using pybrain for the classifier, pandas to hack my way through the data, and pygal for the graphs (far easier than matplotlib). And a lot of extra useful things implemented in the utils.py file, mostly to abstract the data processing I need before I feed the classifier.

# %%
from random import random

from IPython.display import SVG
import pygal

from pybrain.structure import SigmoidLayer
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.datasets import ClassificationDataSet
from pybrain.utilities import percentError

from utils import get_matches, get_team_stats, extract_samples, normalize, split_samples, graph_teams_stat_bars, graph_matches_results_scatter

# %% [markdown]
# Configs
# -------

# %%
# the features I will feed to the classifier as input data.
input_features = ['year',
                  'matches_won_percent',
                  'podium_score_yearly',
                  'matches_won_percent_2',
                  'podium_score_yearly_2',]

# the feature giving the result the classifier must learn to predict (I recommend allways using 'winner')
output_feature = 'winner'

# used to avoid including tied matches in the learning process. I found this greatly improves the classifier accuracy.
# I know there will be some ties, but I'm willing to fail on those and have better accuracy with all the rest.
# at this point, this code will break if you set it to False, because the network uses a sigmoid function with a 
# threeshold for output, so it is able to distinquish only 2 kinds of results.
exclude_ties = True

# used to duplicate matches data, reversing the teams (team1->team2, and viceversa). 
# This helps on visualizations, and also improves precission of the predictions avoiding a dependence on the
# order of the teams from the input.
duplicate_with_reversed = True

# %%
def show(graph):
    '''Small utility to display pygal graphs'''
    return SVG(graph.render())

# %% [markdown]
# Team stats
# ----------
#
# First we need the teams stats. We can't feed the classifier inputs like ('Argentina', 'Brazil'), we need to give it numbers. And not any numbers, not just ids, but numbers that could be somewhat related to the result of the matches.
#
# For example: the percentage of won matches of each team is something that could have an impact in the result, so that stat is a very good candidate.
#
# We just calculate a lots of stats per team, and after we will decide which ones to use.

# %%
team_stats = get_team_stats()
team_stats
# Out:
#                        matches_played  matches_won  years_played  \
# team
# Brazil                             89           63            16
# Canada                              3            0             1
# Serbia and Montenegro               3            0             1
# Kuwait                              3            0             1
# Scotland                           23            4             8
# Costa Rica                         10            3             3
# Ivory Coast                         6            2             2
# Wales                               5            1             1
# Argentina                          64           33            13
# Bolivia                             4            0             2
# Cameroon                           20            4             6
# Ecuador                             7            3             2
# Ghana                               9            4             2
# Saudi Arabia                       13            2             4
# Australia                          10            2             3
# Iran                                9            1             3
# Algeria                             9            2             3
# El Salvador                         6            0             2
# Republic of Ireland                13            2             3
# Slovenia                            6            1             2
# Chile                              26            7             7
# Belgium                            32           10             8
# Haiti                               3            0             1
# Iraq                                3            0             1
# Spain                              53           27            12
# China PR                            3            0             1
# Netherlands                        41           22             7
# Denmark                            16            8             4
# Poland                             30           15             6
# Morocco                            13            2             4
# ...                               ...          ...           ...
# Slovakia                            4            1             1
# Peru                               13            4             3
# Norway                              7            2             2
# Nigeria                            14            4             4
# Israel                              3            0             1
# Zaire                               3            0             1
# Czechoslovakia                     23            7             6
# Austria                            25           10             6
# Togo                                3            0             1
# Germany                            98           59            15
# Ukraine                             5            2             1
# Northern Ireland                   13            3             3
# United States                      25            5             7
# Trinidad and Tobago                 3            0             1
# Sweden                             41           14             9
# Hungary                            26           11             7
# Russia                             37           17             9
# Bulgaria                           26            3             7
# North Korea                         7            1             2
# Romania                            16            7             4
# Angola                              3            0             1
# Portugal                           23           12             5
# Mexico                             46           12            13
# Tunisia                            12            1             4
# Serbia                              3            1             1
# Senegal                             5            2             1
# Yugoslavia                         34           14             8
# Greece                              6            1             2
# Paraguay                           25            6             7
# Japan                              14            4             4
#
#                        podium_score  cups_won  matches_won_percent  \
# team
# Brazil                          102         5            70.786517
# Canada                            0         0             0.000000
# Serbia and Montenegro             0         0             0.000000
# Kuwait                            0         0             0.000000
# Scotland                          0         0            17.391304
# Costa Rica                        0         0            30.000000
# Ivory Coast                       0         0            33.333333
# Wales                             0         0            20.000000
# Argentina                        40         2            51.562500
# Bolivia                           0         0             0.000000
# Cameroon                          0         0            20.000000
# Ecuador                           0         0            42.857143
# Ghana                             0         0            44.444444
# Saudi Arabia                      0         0            15.384615
# Australia                         0         0            20.000000
# Iran                              0         0            11.111111
# Algeria                           0         0            22.222222
# El Salvador                       0         0             0.000000
# Republic of Ireland               0         0            15.384615
# Slovenia                          0         0            16.666667
# Chile                             4         0            26.923077
# Belgium                           2         0            31.250000
# Haiti                             0         0             0.000000
# Iraq                              0         0             0.000000
# Spain                            18         1            50.943396
# China PR                          0         0             0.000000
# Netherlands                      26         0            53.658537
# Denmark                           0         0            50.000000
# Poland                            8         0            50.000000
# Morocco                           0         0            15.384615
# ...                             ...       ...                  ...
# Slovakia                          0         0            25.000000
# Peru                              0         0            30.769231
# Norway                            0         0            28.571429
# Nigeria                           0         0            28.571429
# Israel                            0         0             0.000000
# Zaire                             0         0             0.000000
# Czechoslovakia                    8         0            30.434783
# Austria                           4         0            40.000000
# Togo                              0         0             0.000000
# Germany                          94         3            60.204082
# Ukraine                           0         0            40.000000
# Northern Ireland                  0         0            23.076923
# United States                     0         0            20.000000
# Trinidad and Tobago               0         0             0.000000
# Sweden                           16         0            34.146341
# Hungary                           8         0            42.307692
# Russia                            2         0            45.945946
# Bulgaria                          2         0            11.538462
# North Korea                       0         0            14.285714
# Romania                           0         0            43.750000
# Angola                            0         0             0.000000
# Portugal                          6         0            52.173913
# Mexico                            0         0            26.086957
# Tunisia                           0         0             8.333333
# Serbia                            0         0            33.333333
# Senegal                           0         0            40.000000
# Yugoslavia                        2         0            41.176471
# Greece                            0         0            16.666667
# Paraguay                          0         0            24.000000
# Japan                             0         0            28.571429
#
#                        podium_score_yearly  cups_won_yearly
# team
# Brazil                            6.375000         0.312500
# Canada                            0.000000         0.000000
# Serbia and Montenegro             0.000000         0.000000
# Kuwait                            0.000000         0.000000
# Scotland                          0.000000         0.000000
# Costa Rica                        0.000000         0.000000
# Ivory Coast                       0.000000         0.000000
# Wales                             0.000000         0.000000
# Argentina                         3.076923         0.153846
# Bolivia                           0.000000         0.000000
# Cameroon                          0.000000         0.000000
# Ecuador                           0.000000         0.000000
# Ghana                             0.000000         0.000000
# Saudi Arabia                      0.000000         0.000000
# Australia                         0.000000         0.000000
# Iran                              0.000000         0.000000
# Algeria                           0.000000         0.000000
# El Salvador                       0.000000         0.000000
# Republic of Ireland               0.000000         0.000000
# Slovenia                          0.000000         0.000000
# Chile                             0.571429         0.000000
# Belgium                           0.250000         0.000000
# Haiti                             0.000000         0.000000
# Iraq                              0.000000         0.000000
# Spain                             1.500000         0.083333
# China PR                          0.000000         0.000000
# Netherlands                       3.714286         0.000000
# Denmark                           0.000000         0.000000
# Poland                            1.333333         0.000000
# Morocco                           0.000000         0.000000
# ...                                    ...              ...
# Slovakia                          0.000000         0.000000
# Peru                              0.000000         0.000000
# Norway                            0.000000         0.000000
# Nigeria                           0.000000         0.000000
# Israel                            0.000000         0.000000
# Zaire                             0.000000         0.000000
# Czechoslovakia                    1.333333         0.000000
# Austria                           0.666667         0.000000
# Togo                              0.000000         0.000000
# Germany                           6.266667         0.200000
# Ukraine                           0.000000         0.000000
# Northern Ireland                  0.000000         0.000000
# United States                     0.000000         0.000000
# Trinidad and Tobago               0.000000         0.000000
# Sweden                            1.777778         0.000000
# Hungary                           1.142857         0.000000
# Russia                            0.222222         0.000000
# Bulgaria                          0.285714         0.000000
# North Korea                       0.000000         0.000000
# Romania                           0.000000         0.000000
# Angola                            0.000000         0.000000
# Portugal                          1.200000         0.000000
# Mexico                            0.000000         0.000000
# Tunisia                           0.000000         0.000000
# Serbia                            0.000000         0.000000
# Senegal                           0.000000         0.000000
# Yugoslavia                        0.250000         0.000000
# Greece                            0.000000         0.000000
# Paraguay                          0.000000         0.000000
# Japan                             0.000000         0.000000
#
# [76 rows x 8 columns]

# %% [markdown]
# Lets visualize some of those stats, just because it helps paint a bigger picture on how good the teams are.
#
# (you can hoover with your mouse on the '...' from the x axys to see the team name)

# %%
show(graph_teams_stat_bars(team_stats, 'matches_won_percent'))

# %% [markdown]
# Pudium score is an invented measure on how good the teams are by looking at the 4 first teams from each cup. The first team receives 8 points, the second 4, the third 2, and the fourth 1. All the rest receive 0 points. As you can see, the scoring is exponential, because each position implies an exponentially bigger amount of matches won than the next one.

# %%
show(graph_teams_stat_bars(team_stats, 'podium_score_yearly'))

# %% [markdown]
# Matches
# -------
#
# Now we need to get the matches data, including the "reversed" duplication of matches, and adding the team stats in each match.

# %%
matches = get_matches(with_team_stats=True,
                      duplicate_with_reversed=duplicate_with_reversed,
                      exclude_ties=exclude_ties)
        
matches
# Out:
#       score1  score2          team1           team2  year  score_diff  winner  \
# 0          4       0         Brazil          Mexico  1950           4       1
# 1          3       0     Yugoslavia     Switzerland  1950           3       1
# 3          4       1     Yugoslavia          Mexico  1950           3       1
# 4          2       0         Brazil      Yugoslavia  1950           2       1
# 5          2       1    Switzerland          Mexico  1950           1       1
# 6          2       0        England           Chile  1950           2       1
# 7          3       1          Spain   United States  1950           2       1
# 8          2       0          Spain           Chile  1950           2       1
# 9          1       0  United States         England  1950           1       1
# 10         1       0          Spain         England  1950           1       1
# 11         5       2          Chile   United States  1950           3       1
# 12         3       2         Sweden           Italy  1950           1       1
# 14         2       0          Italy        Paraguay  1950           2       1
# 15         8       0        Uruguay         Bolivia  1950           8       1
# 17         7       1         Brazil          Sweden  1950           6       1
# 18         6       1         Brazil           Spain  1950           5       1
# 19         3       2        Uruguay          Sweden  1950           1       1
# 20         3       1         Sweden           Spain  1950           2       1
# 21         2       1        Uruguay          Brazil  1950           1       1
# 22         5       0         Brazil          Mexico  1954           5       1
# 23         1       0     Yugoslavia          France  1954           1       1
# 25         3       2         France          Mexico  1954           1       1
# 26         4       1        Germany          Turkey  1954           3       1
# 27         9       0        Hungary     South Korea  1954           9       1
# 28         8       3        Hungary         Germany  1954           5       1
# 29         7       0         Turkey     South Korea  1954           7       1
# 30         7       2        Germany          Turkey  1954           5       1
# 31         2       0        Uruguay  Czechoslovakia  1954           2       1
# 32         1       0        Austria        Scotland  1954           1       1
# 33         7       0        Uruguay        Scotland  1954           7       1
# ...      ...     ...            ...             ...   ...         ...     ...
# 1447       0       1       Cameroon           Japan  2010          -1       2
# 1448       0       1          Japan     Netherlands  2010          -1       2
# 1449       2       1        Denmark        Cameroon  2010           1       1
# 1450       3       1          Japan         Denmark  2010           2       1
# 1451       2       1    Netherlands        Cameroon  2010           1       1
# 1454       2       0       Paraguay        Slovakia  2010           2       1
# 1456       2       3          Italy        Slovakia  2010          -1       2
# 1459       1       2    North Korea          Brazil  2010          -1       2
# 1460       1       3    Ivory Coast          Brazil  2010          -2       2
# 1461       0       7    North Korea        Portugal  2010          -7       2
# 1463       3       0    Ivory Coast     North Korea  2010           3       1
# 1464       1       0          Chile        Honduras  2010           1       1
# 1465       1       0    Switzerland           Spain  2010           1       1
# 1466       0       1    Switzerland           Chile  2010          -1       2
# 1467       0       2       Honduras           Spain  2010          -2       2
# 1468       2       1          Spain           Chile  2010           1       1
# 1470       1       2    South Korea         Uruguay  2010          -1       2
# 1471       2       1          Ghana   United States  2010           1       1
# 1472       1       4        England         Germany  2010          -3       2
# 1473       1       3         Mexico       Argentina  2010          -2       2
# 1474       1       2       Slovakia     Netherlands  2010          -1       2
# 1475       0       3          Chile          Brazil  2010          -3       2
# 1477       0       1       Portugal           Spain  2010          -1       2
# 1478       1       2         Brazil     Netherlands  2010          -1       2
# 1480       4       0        Germany       Argentina  2010           4       1
# 1481       1       0          Spain        Paraguay  2010           1       1
# 1482       3       2    Netherlands         Uruguay  2010           1       1
# 1483       1       0          Spain         Germany  2010           1       1
# 1484       3       2        Germany         Uruguay  2010           1       1
# 1485       1       0          Spain     Netherlands  2010           1       1
#
#       matches_played  matches_won  years_played      ...       \
# 0                 89           63            16      ...
# 1                 34           14             8      ...
# 3                 34           14             8      ...
# 4                 89           63            16      ...
# 5                 24            7             7      ...
# 6                 59           26            13      ...
# 7                 53           27            12      ...
# 8                 53           27            12      ...
# 9                 25            5             7      ...
# 10                53           27            12      ...
# 11                26            7             7      ...
# 12                41           14             9      ...
# 14                71           36            15      ...
# 15                43           14            10      ...
# 17                89           63            16      ...
# 18                89           63            16      ...
# 19                43           14            10      ...
# 20                41           14             9      ...
# 21                43           14            10      ...
# 22                89           63            16      ...
# 23                34           14             8      ...
# 25                48           23            10      ...
# 26                98           59            15      ...
# 27                26           11             7      ...
# 28                26           11             7      ...
# 29                10            5             2      ...
# 30                98           59            15      ...
# 31                43           14            10      ...
# 32                25           10             6      ...
# 33                43           14            10      ...
# ...              ...          ...           ...      ...
# 1447              20            4             6      ...
# 1448              14            4             4      ...
# 1449              16            8             4      ...
# 1450              14            4             4      ...
# 1451              41           22             7      ...
# 1454              25            6             7      ...
# 1456              71           36            15      ...
# 1459               7            1             2      ...
# 1460               6            2             2      ...
# 1461               7            1             2      ...
# 1463               6            2             2      ...
# 1464              26            7             7      ...
# 1465              24            7             7      ...
# 1466              24            7             7      ...
# 1467               6            0             2      ...
# 1468              53           27            12      ...
# 1470              28            5             8      ...
# 1471               9            4             2      ...
# 1472              59           26            13      ...
# 1473              46           12            13      ...
# 1474               4            1             1      ...
# 1475              26            7             7      ...
# 1477              23           12             5      ...
# 1478              89           63            16      ...
# 1480              98           59            15      ...
# 1481              53           27            12      ...
# 1482              41           22             7      ...
# 1483              53           27            12      ...
# 1484              98           59            15      ...
# 1485              53           27            12      ...
#
#       podium_score_yearly  cups_won_yearly  matches_played_2  matches_won_2  \
# 0                6.375000         0.312500                46             12
# 1                0.250000         0.000000                24              7
# 3                0.250000         0.000000                46             12
# 4                6.375000         0.312500                34             14
# 5                0.000000         0.000000                46             12
# 6                1.384615         0.076923                26              7
# 7                1.500000         0.083333                25              5
# 8                1.500000         0.083333                26              7
# 9                0.000000         0.000000                59             26
# 10               1.500000         0.083333                59             26
# 11               0.571429         0.000000                25              5
# 12               1.777778         0.000000                71             36
# 14               3.600000         0.133333                25              6
# 15               2.200000         0.100000                 4              0
# 17               6.375000         0.312500                41             14
# 18               6.375000         0.312500                53             27
# 19               2.200000         0.100000                41             14
# 20               1.777778         0.000000                53             27
# 21               2.200000         0.100000                89             63
# 22               6.375000         0.312500                46             12
# 23               0.250000         0.000000                48             23
# 25               3.400000         0.100000                46             12
# 26               6.266667         0.200000                10              5
# 27               1.142857         0.000000                28              5
# 28               1.142857         0.000000                98             59
# 29               2.000000         0.000000                28              5
# 30               6.266667         0.200000                10              5
# 31               2.200000         0.100000                23              7
# 32               0.666667         0.000000                23              4
# 33               2.200000         0.100000                23              4
# ...                   ...              ...               ...            ...
# 1447             0.000000         0.000000                14              4
# 1448             0.000000         0.000000                41             22
# 1449             0.000000         0.000000                20              4
# 1450             0.000000         0.000000                16              8
# 1451             3.714286         0.000000                20              4
# 1454             0.000000         0.000000                 4              1
# 1456             3.600000         0.133333                 4              1
# 1459             0.000000         0.000000                89             63
# 1460             0.000000         0.000000                89             63
# 1461             0.000000         0.000000                23             12
# 1463             0.000000         0.000000                 7              1
# 1464             0.571429         0.000000                 6              0
# 1465             0.000000         0.000000                53             27
# 1466             0.000000         0.000000                26              7
# 1467             0.000000         0.000000                53             27
# 1468             1.500000         0.083333                26              7
# 1470             0.250000         0.000000                43             14
# 1471             0.000000         0.000000                25              5
# 1472             1.384615         0.076923                98             59
# 1473             0.000000         0.000000                64             33
# 1474             0.000000         0.000000                41             22
# 1475             0.571429         0.000000                89             63
# 1477             1.200000         0.000000                53             27
# 1478             6.375000         0.312500                41             22
# 1480             6.266667         0.200000                64             33
# 1481             1.500000         0.083333                25              6
# 1482             3.714286         0.000000                43             14
# 1483             1.500000         0.083333                98             59
# 1484             6.266667         0.200000                43             14
# 1485             1.500000         0.083333                41             22
#
#       years_played_2  podium_score_2  cups_won_2  matches_won_percent_2  \
# 0                 13               0           0              26.086957
# 1                  7               0           0              29.166667
# 3                 13               0           0              26.086957
# 4                  8               2           0              41.176471
# 5                 13               0           0              26.086957
# 6                  7               4           0              26.923077
# 7                  7               0           0              20.000000
# 8                  7               4           0              26.923077
# 9                 13              18           1              44.067797
# 10                13              18           1              44.067797
# 11                 7               0           0              20.000000
# 12                15              54           2              50.704225
# 14                 7               0           0              24.000000
# 15                 2               0           0               0.000000
# 17                 9              16           0              34.146341
# 18                12              18           1              50.943396
# 19                 9              16           0              34.146341
# 20                12              18           1              50.943396
# 21                16             102           5              70.786517
# 22                13               0           0              26.086957
# 23                10              34           1              47.916667
# 25                13               0           0              26.086957
# 26                 2               4           0              50.000000
# 27                 8               2           0              17.857143
# 28                15              94           3              60.204082
# 29                 8               2           0              17.857143
# 30                 2               4           0              50.000000
# 31                 6               8           0              30.434783
# 32                 8               0           0              17.391304
# 33                 8               0           0              17.391304
# ...              ...             ...         ...                    ...
# 1447               4               0           0              28.571429
# 1448               7              26           0              53.658537
# 1449               6               0           0              20.000000
# 1450               4               0           0              50.000000
# 1451               6               0           0              20.000000
# 1454               1               0           0              25.000000
# 1456               1               0           0              25.000000
# 1459              16             102           5              70.786517
# 1460              16             102           5              70.786517
# 1461               5               6           0              52.173913
# 1463               2               0           0              14.285714
# 1464               2               0           0               0.000000
# 1465              12              18           1              50.943396
# 1466               7               4           0              26.923077
# 1467              12              18           1              50.943396
# 1468               7               4           0              26.923077
# 1470              10              22           1              32.558140
# 1471               7               0           0              20.000000
# 1472              15              94           3              60.204082
# 1473              13              40           2              51.562500
# 1474               7              26           0              53.658537
# 1475              16             102           5              70.786517
# 1477              12              18           1              50.943396
# 1478               7              26           0              53.658537
# 1480              13              40           2              51.562500
# 1481               7               0           0              24.000000
# 1482              10              22           1              32.558140
# 1483              15              94           3              60.204082
# 1484              10              22           1              32.558140
# 1485               7              26           0              53.658537
#
#       podium_score_yearly_2  cups_won_yearly_2
# 0                  0.000000           0.000000
# 1                  0.000000           0.000000
# 3                  0.000000           0.000000
# 4                  0.250000           0.000000
# 5                  0.000000           0.000000
# 6                  0.571429           0.000000
# 7                  0.000000           0.000000
# 8                  0.571429           0.000000
# 9                  1.384615           0.076923
# 10                 1.384615           0.076923
# 11                 0.000000           0.000000
# 12                 3.600000           0.133333
# 14                 0.000000           0.000000
# 15                 0.000000           0.000000
# 17                 1.777778           0.000000
# 18                 1.500000           0.083333
# 19                 1.777778           0.000000
# 20                 1.500000           0.083333
# 21                 6.375000           0.312500
# 22                 0.000000           0.000000
# 23                 3.400000           0.100000
# 25                 0.000000           0.000000
# 26                 2.000000           0.000000
# 27                 0.250000           0.000000
# 28                 6.266667           0.200000
# 29                 0.250000           0.000000
# 30                 2.000000           0.000000
# 31                 1.333333           0.000000
# 32                 0.000000           0.000000
# 33                 0.000000           0.000000
# ...                     ...                ...
# 1447               0.000000           0.000000
# 1448               3.714286           0.000000
# 1449               0.000000           0.000000
# 1450               0.000000           0.000000
# 1451               0.000000           0.000000
# 1454               0.000000           0.000000
# 1456               0.000000           0.000000
# 1459               6.375000           0.312500
# 1460               6.375000           0.312500
# 1461               1.200000           0.000000
# 1463               0.000000           0.000000
# 1464               0.000000           0.000000
# 1465               1.500000           0.083333
# 1466               0.571429           0.000000
# 1467               1.500000           0.083333
# 1468               0.571429           0.000000
# 1470               2.200000           0.100000
# 1471               0.000000           0.000000
# 1472               6.266667           0.200000
# 1473               3.076923           0.153846
# 1474               3.714286           0.000000
# 1475               6.375000           0.312500
# 1477               1.500000           0.083333
# 1478               3.714286           0.000000
# 1480               3.076923           0.153846
# 1481               0.000000           0.000000
# 1482               2.200000           0.100000
# 1483               6.266667           0.200000
# 1484               2.200000           0.100000
# 1485               3.714286           0.000000
#
# [1100 rows x 23 columns]

# %% [markdown]
# Are the results able to be classified? Can we see a pattern, some kind of grouping of results based on the stats of bot teams?
#
# Let's try visualizing two of the most interesting ones: matches won percent, and podium score yearly (mean).

# %%
show(graph_matches_results_scatter(matches, 'matches_won_percent', 'matches_won_percent_2'))

# %%
show(graph_matches_results_scatter(matches, 'podium_score_yearly', 'podium_score_yearly_2'))

# %% [markdown]
# Before any conclussions: there is more there than what you can see with your eyes. At some location, there could be more than 1 point, and you only see the one on the top.
#
# The first graph tells us something that most people already expect: there is a small tendency on the result, the team with the better matches won percent tends to win. The second graph also shows a similar relation between podium score yearly and the result, even if it's not visible to the eye because of the overlapping of dots.
#
# But remember, the classifier can learn a lot more than just those simple relations based on the info we give to it. These graphs were just a screening to confirm some basic intuitions.

# %% [markdown]
# Learn
# -----
#
# Ok, now we have everything we need. Lets feed the selected input features to a the neural network classifier, and let it learn.
#
# We have to normalize the data, otherwise the features with smaller values will impose a greater weight on the prediction.
#
# Also, we use a percentage of the inputs to train, but keep the rest "hidden", we don't let the classifier see them while learning. After the training we use those inputs to "test" the ability of the classifier to predict data it has never seen before (and data we already know the correct answer).

# %%
inputs, outputs = extract_samples(matches,
                                  input_features,
                                  output_feature)

normalizer, inputs = normalize(inputs)

train_inputs, train_outputs, test_inputs, test_outputs = split_samples(inputs, outputs)

n = buildNetwork(len(input_features),
                 10 * len(input_features),
                 10 * len(input_features),
                 1,
                 outclass=SigmoidLayer,
                 bias=True)

# %% [markdown]
# To be able to evaluate the results and show progress on the learning cycle, we need these two functions wich help us calculate how well the network can predict the results from the matches used to learn, and the matches it doesn't know.

# %%
def neural_result(input):
    """Call the neural network, and translates its output to a match result."""
    n_output = n.activate(input) 
    if n_output >= 0.5:
        return 2
    else:
        return 1
    
def test_network():
    """Calculate train and test sets errors."""
    print (100 - percentError(map(neural_result, train_inputs), train_outputs), 
           100 - percentError(map(neural_result, test_inputs), test_outputs))

# %% [markdown]
# Create a train set (a kind of dataset that pybrain uses to train neural networks), and display initial accuracy on both sets (train and test).

# %%
train_set = ClassificationDataSet(len(input_features))

for i, input_line in enumerate(train_inputs):
    train_set.addSample(train_inputs[i], [train_outputs[i] - 1])

trainer = BackpropTrainer(n, dataset=train_set, momentum=0.5, weightdecay=0.0)

train_set.assignClasses()

test_network()
# Out:
# (47.21549636803874, 48.90510948905109)

# %% [markdown]
# Train the network, for a given number of iterations. You can re-run this step many times, and it will keep learning, but as you know, if you train too much you can end overfitting the training data (this is visible when the test set accuracy starts to decrease).

# %%
for i in range(20):
    trainer.train()
    test_network()
# Out:
# (72.15496368038741, 69.34306569343066)
# (73.97094430992736, 71.16788321167883)
# (74.21307506053269, 70.8029197080292)
# (74.09200968523002, 69.7080291970803)
# (74.33414043583535, 71.53284671532847)
# (74.93946731234867, 70.07299270072993)
# (74.93946731234867, 70.8029197080292)
# (74.45520581113801, 71.53284671532847)
# (75.54479418886199, 70.43795620437956)
# (75.66585956416465, 70.8029197080292)
# (74.33414043583535, 69.7080291970803)
# (76.02905569007264, 70.43795620437956)
# (75.30266343825666, 71.16788321167883)
# (75.30266343825666, 70.07299270072993)
# (75.66585956416465, 71.16788321167883)
# (75.06053268765133, 71.16788321167883)
# (75.66585956416465, 70.07299270072993)
# (75.54479418886199, 70.07299270072993)
# (76.1501210653753, 70.07299270072993)
# (75.78692493946731, 70.8029197080292)

# %% [markdown]
# The closer this score is to 100%, the better the classifier is doing its predictions. A score of 100 means the classifier allways predicts the exact real result, something impossible.
#
# And something around 75% sounds impressive, but in fact is not **that** good. It's pretty good, but consider that just throwing a coin will get you 50%. So this sits in the middle between throwing a coin and having a time machine.

# %% [markdown]
# Predict
# -------
#
# With the classifier already trained, we can start making predictions. But we need a little function able to translate inputs like this: (2014, 'Argentina', 'Brazil'), to the numeric inputs the classifier expects (based on the input features).
#
# This function does the conversion, also normalizes the data with the same normalizer used before, and then just asks the classifier for the prediction.

# %%
def predict(year, team1, team2):
    inputs = []
    
    for feature in input_features:
        from_team_2 = '_2' in feature
        feature = feature.replace('_2', '')
        
        if feature in team_stats.columns.values:
            team = team2 if from_team_2 else team1
            value = team_stats.loc[team, feature]
        elif feature == 'year':
            value = year
        else:
            raise ValueError("Don't know where to get feature: " + feature)
            
        inputs.append(value)
        
    inputs = normalizer.transform(inputs)
    result = neural_result(inputs)
    
    if result == 0:
        return 'tie'
    elif result == 1:
        return team1
    elif result == 2:
        return team2
    else:
        return 'Unknown result: ' + str(result)

# %% [markdown]
# Some predictions about the past, compared to real results:
# ----------------------------------------------------------
#
# Even while we know those results and some of them where used to train, that doesn't guarantee the real result is what the classifier will predict.

# %%
predict(1950, 'Mexico', 'Brazil')  # real result: 4-0 wins Brazil
# Out:
# 'Brazil'

# %%
predict(1990, 'United Arab Emirates', 'Colombia')  # real result: 2-0 wins Colombia
# Out:
# 'Colombia'

# %%
predict(2002, 'South Africa', 'Spain')  # real result: 2-3 wins Spain
# Out:
# 'Spain'

# %%
predict(2010, 'Japan', 'Cameroon')  # real result: 1-0 wins Japan
# Out:
# 'Japan'

# %% [markdown]
# Some predictions about the future:
# ----------------------------------
#
# (at least these where "future" at the moment of programming)

# %%
predict(2014, 'Argentina', 'Brazil')
# Out:
# 'Brazil'

# %%
predict(2014, 'Spain', 'Haiti')
# Out:
# 'Spain'

# %%
predict(2014, 'Russia', 'Germany')
# Out:
# 'Germany'

# %%
predict(2014, 'Russia', 'Russia')
# Out:
# 'Russia'

# %% [markdown]
# # Post Review After the Games
#
# Results are in http://www.fifa.com/worldcup/matches/

# %% [markdown]
# ## Round 16

# %%
def display_prediction_result(year, team1, team2, actual_winner):
    predicted_result = predict(year, team1, team2)
    
    is_prediction_correct = actual_winner
    if is_prediction_correct:
        print "Prediction is \x1b[32mCORRECT\x1b[0m: %s won" % predicted_result
    else:
        print "Prediction is \x1b[31mWRONG\x1b[0m: Predicted Reslt [%s] != Actual Result [%s]" % (predicted_result, actual_winner)

    return 1 if is_prediction_correct else 0

# %%
number_of_correct = 0
number_of_predictions = 0

# %%
number_of_correct += display_prediction_result(2014, 'Brazil', 'Chile', 'Brazil')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Brazil won

# %%
number_of_correct += display_prediction_result(2014, 'Colombia', 'Uruguay', 'Colombia')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Uruguay won

# %%
number_of_correct += display_prediction_result(2014, 'France', 'Nigeria', 'France')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: France won

# %%
number_of_correct += display_prediction_result(2014, 'Germany', 'Algeria', 'Germany')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Germany won

# %%
number_of_correct += display_prediction_result(2014, 'Netherlands', 'Mexico', 'Netherlands')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Netherlands won

# %%
number_of_correct += display_prediction_result(2014, 'Costa Rica', 'Greece', 'Costa Rica')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Costa Rica won

# %%
number_of_correct += display_prediction_result(2014, 'Argentina', 'Switzerland', 'Argentina')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Argentina won

# %%
number_of_correct += display_prediction_result(2014, 'Belgium', 'United States', 'Belgium')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Belgium won

# %% [markdown]
# ## Quarter Finals

# %%
number_of_correct += display_prediction_result(2014, 'Brazil', 'Colombia', 'Brazil')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Brazil won

# %%
number_of_correct += display_prediction_result(2014, 'France', 'Germany', 'Germany')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Germany won

# %%
number_of_correct += display_prediction_result(2014, 'Netherlands', 'Costa Rica', 'Netherlands')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Netherlands won

# %%
number_of_correct += display_prediction_result(2014, 'Argentina', 'Belgium', 'Argentina')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Argentina won

# %% [markdown]
# ## Semi Finals

# %%
number_of_correct += display_prediction_result(2014, 'Brazil', 'Germany', 'Germany')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Brazil won

# %%
number_of_correct += display_prediction_result(2014, 'Netherlands', 'Argentina', 'Argentina')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Argentina won

# %% [markdown]
# ## Finals

# %%
number_of_correct += display_prediction_result(2014, 'Germany', 'Argentina', 'Germany')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Germany won

# %%
number_of_correct += display_prediction_result(2014, 'Brazil', 'Netherlands', 'Netherlands')
number_of_predictions += 1
# Out:
# Prediction is CORRECT: Brazil won

# %%
print "Got %d out of %d correct (or %.2f%%)." % (number_of_correct, number_of_predictions, number_of_correct/(number_of_predictions * 1.0))
# Out:
# Got 16 out of 16 correct (or 1.00%).
